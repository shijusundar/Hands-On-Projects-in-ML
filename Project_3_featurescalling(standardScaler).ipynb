# %% [markdown]
# ***Import required libraries***

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ***Select a random values and plot***

# %%
R=np.random.random([100,1])+3
plt.plot(R)

# %% [markdown]
# ***Mean***

# %%
np.mean(R)
# Out:
# 3.4934125262680724

# %% [markdown]
# ***Standard Deviation***

# %%
np.std(R)
# Out:
# 0.27459220657467953

# %% [markdown]
# ***Feature Scalling***

# %%
scalar=StandardScaler()

# %%
scalar.fit(R)
# Out:
# StandardScaler()

# %%
scalar.mean_
# Out:
# array([3.49341253])

# %%
RScaled=scalar.transform(R)

# %%
plt.plot(RScaled)

# %%
np.mean(RScaled)
# Out:
# 3.846922780326167e-15

# %%
# !ls
# Out:
# housing_data.csv  sample_data

# %% [markdown]
# ***Load the housing data and feature scalling it and predict output,MSE also***

# %%
data=np.loadtxt(open("housing_data.csv","rb"),delimiter=",")

# %%
data.shape
# Out:
# (506, 14)

# %%
x=data[:,0:13]
y=data[:,13]
y=y.reshape(-1,1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
scalar.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train=scalar.transform(x_train)

x_test=scalar.transform(x_test)
print(x_train)

# %%
model=linear_model.LinearRegression(fit_intercept=True)
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
error=mean_squared_error(y_pred,y_test)
print(error)
# Out:
# 24.311426929693507
